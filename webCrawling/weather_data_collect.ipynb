# %%
import requests
from bs4 import BeautifulSoup as bs
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
# user-agent
h  = {'user-agent':"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36" }

# %%
param={
    "stn":"156",
    "yy":"2023",
    "mm":"2",
    "obs":"1"
}

# %%
url = "https://www.weather.go.kr/w/obs-climate/land/past-obs/obs-by-day.do?"

res = requests.get(url, headers=h, params=param)
page = bs(res.text, 'lxml')

# %%
test_list = page.select("tbody > tr")
test_list
# Out:
# [<tr>
#  <th>유인관서(유)</th>
#  <td>무인관측요소 + 날씨(기상현상), 구름, 적설</td>
#  </tr>,
#  <tr>
#  <th class="border_bottom">무인관서(무)</th>
#  <td>기온, 강수량, 바람, 습도, 일조시간</td>
#  </tr>,
#  <tr>
#  <th class="border_bottom">이전관서(구)</th>
#  <td>기존 관측지점에 (구)를 붙여 표시</td>
#  </tr>,
#  <tr>
#  <td>
#  <span> </span>
#  </td>
#  <td>
#  <span> </span>
#  </td>
#  <td>
#  <span> </span>
#  </td>
#  <td>
#  <span>1일</span>
#  </td>
#  <td>
#  <span>2일</span>
#  </td>
#  <td>
#  <span>3일</span>
#  </td>
#  <td>
#  <span>4일</span>
#  </td>
#
#
#
#
#
#
#
#
#
#
#
#  1일
#
#
#  2일
#
#
#  3일
#
#
#  4일
#
#  </tr>,
#  <tr>
#  <td>
#  <span> </span>
#  </td>
#  <td>
#  <span> </span>
#  </td>
#  <td>
#  <span> </span>
#  </td>
#  <td>
#  <span>평균기온:3.9℃</span>
#  <span></span>
#  <span><br/></span>
#  <span>최고기온:10.7℃</span>
#  <span></span>
#  <span><br/></span>
#  <span>최저기온:-0.8℃</span>
#  <span></span>
#  <span><br/></span>
#  <span>평균운량:5.3</span>
#  <span></span>
#  <span><br/></span>
#  <span>일강수량: - </span>
# ...

# %%
cnt = 0;
date = []
weather = []
for i in test_list:
    if(cnt%2==0):
        weather.append(i.text.strip())
    else:
        date.append(i.text.strip())
    cnt = cnt+1j

# %%
# Out:
# '1일\n\n\n2일\n\n\n3일\n\n\n4일\n\n\n\n\xa0\n\n\n\xa0\n\n\n\xa0\n\n\n1일\n\n\n2일\n\n\n3일\n\n\n4일'
