# %% [markdown]
# <h4> 기본 그래프 그리기
# <br>
# <a> plt.plot([1,2,3,4])</a>

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[1,4,9,16])
plt.show()

# %% [markdown]
# <h4> 스타일 지정하기
# <br>

# %%
plt.plot([1,2,3,4],[1,4,9,16],'ro')
# X,Y좌표
# 'ro' 는 RED-O형
plt.axis([0,6,0,20])
# (axis(X)좌표 0~6범위)
# (axis(Y)좌표 0~20범위)
plt.show()

# %% [markdown]
# <H4>여러 개의 그래프 그리기

# %%
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0.,5.,0.2)
# 200ms 간격으로 균일하게 샘플된 시간.
plt.plot(t, t,'r--', t,t**2, 'bs', t,t**3, 'g^')
#기본 t의 값은 빨간 직선 ---
# t의 제곱은 파란색 사각형
# t의 세제곱은 초록색 삼각형
plt.show()

# %% [markdown]
# <H4>Matplotlib 숫자 입력하기

# %%
import matplotlib.pyplot as plt

plt.plot([2,3,5,10])
plt.show()

# %% [markdown]
# <h5> X,Y 값 입력하기

# %%
plt.plot([1,2,3,4],[2,3,5,10])
plt.show()

# %% [markdown]
# <h4> 레이블이 있는 데이터 사용하기

# %%
data_dict = {'data_x':[1,2,3,4,5],'data_y':[2,3,5,10,8]}

plt.plot('data_x', 'data_y',data=data_dict)
plt.show()

# %% [markdown]
# <H4> Matplotlib 축 레이블 사용하기

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[1,4,9,16])
# x축 레이블 이름 지정
plt.xlabel("X-Label")
# y축 레이블 이름 지정
plt.ylabel("Y-Label")
plt.show()

# %% [markdown]
# <h4> 여백 지정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4],[2,3,5,10])
plt.xlabel('X-Axis', labelpad=15)
plt.ylabel('Y-Axis', labelpad=20)
plt.show()

# %% [markdown]
# <h4> 폰트 설정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4],[2,3,5,10])
plt.xlabel('X-Axis',labelpad=15,fontdict={'family': 'serif','color':'b', 'weight': 'bold','size' : 14})
plt.ylabel('Y-Axis',labelpad=20,fontdict={'family': 'fantasy','color':'pink', 'weight': 'normal','size' : 'xx-large'})
plt.show()

# %% [markdown]
# <H4> 레이블 위치 지정하기

# %%
plt.plot([1,2,3,4],[2,3,5,10])
plt.xlabel('X-Axis', loc = 'right')
plt.ylabel('Y-Axis', loc = 'top')
plt.show()

# %% [markdown]
# <h4> Matplotlib 범례 표시하기

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4],[2,3,5,10],label='Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend()

plt.show()

# %% [markdown]
# <h4> 위치 지정하기
#
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4],[2,3,5,10],label='Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend(loc=(1.0,1.0))

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4],[2,3,5,10],label='Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend(loc = 'lower right')

plt.show()

# %% [markdown]
# <h4> 열 개수 지정하기
#
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4],[2,3,5,10],label = 'Price ($)')
plt.plot([1,2,3,4],[3,5,9,7], label = 'Demand(#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend(loc='best', ncol=2)
plt.show()

# %% [markdown]
# <H4> 폰트 수정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4],[2,3,5,10],label = 'Price ($)')
plt.plot([1,2,3,4],[3,5,9,7], label = 'Demand(#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend(loc='best', ncol=2,fontsize = 14)
plt.show()

# %% [markdown]
# <h4> 범례 테두리 꾸미기
#
# - frameon : 범례 텍스트 상자의 테두리를 표시할지 여부 지정
# - shadow : 텍스트 상자에 그림자를 표시할 수 있다.

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc='best')
plt.legend(loc='best', ncol=2, fontsize=14, frameon=True, shadow=True)

plt.show()

# %% [markdown]
# <h4> 05.Matplotlib 축 범위 지정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4],[2,3,5,10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# x의 값 0~5
plt.xlim([0,5])
# y의 값은 0~20
plt.ylim([0,20])

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4],[2,3,5,10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

# xlim , ylim을 이용하여 해당 축에 대해서 지정 가능
# plt.xlim([0,5])
# plt.ylim([0,20])

# axis() 함수를 이용하여 한번에 최소, 최대값이 지정가능
# x,y축의 범위 : [xmin, xmax, ymin, ymax]
plt.axis([0,5,0,20])

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4],[2,3,5,10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# scaled 사용 시 x,y축이 지정한 길이와 같게 나온다.
plt.axis('scaled')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4],[2,3,5,10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# 축 길이가 동일하게 표시된다.
plt.axis('square')
plt.show()

# %% [markdown]
# <h4> 축 범위 얻기

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4],[2,3,5,10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
x_range , y_range = plt.xlim(),plt.ylim()
print(x_range, y_range)

axis_range = plt.axis('scaled')
print(axis_range)

plt.show()
# Out:
# (0.85, 4.15) (1.6, 10.4)
# (0.85, 4.15, 1.6, 10.4)

# %% [markdown]
# <H4> 06.Matplotlib 선 종류 지정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3],[4,4,4],'-', color='C0', label='Solid')
plt.plot([1,2,3],[3,3,3],'--', color='C0', label='Dashed')
plt.plot([1,2,3],[2,2,2],':', color='C0', label='Dotted')
plt.plot([1,2,3],[1,1,1],'-.', color='C0', label='Dash-dot')

# 축 이름 설정
plt.xlabel('X_Axis')
plt.ylabel('Y-Axis')

# 그래프 길이 조정
plt.axis([0.8,3.2,0.5,5.0])

# 범례 지정
plt.legend(loc='upper right', ncol =4)
plt.show()

# %% [markdown]
# <h5> lineStyle 지정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', color='C0', label="'solid'")
plt.plot([1, 2, 3], [3, 3, 3], linestyle='dashed', color='C0', label="'dashed'")
plt.plot([1, 2, 3], [2, 2, 2], linestyle='dotted', color='C0', label="'dotted'")
plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashdot', color='C0', label="'dashdot'")
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=4)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h5> 선 끝 모양 지정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid',linewidth = 10,solid_capstyle='butt', color='C0', label='solid+butt')
plt.plot([1, 2, 3], [3, 3, 3], linestyle='solid',linewidth = 10,solid_capstyle='round', color='C0', label='solid+round')
plt.plot([1, 2, 3], [2, 2, 2], linestyle='dashed',linewidth = 10,dash_capstyle='butt', color='C1', label='dashed+butt')
plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashed',linewidth = 10,dash_capstyle='round', color='C1', label='dashed+round')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=2)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 07. Matplotlib 마커 지정하기

# %%
import matplotlib.pyplot as plt

# 'bo' ==> 파란색 점
plt.plot([1,2,3,4],[2,3,5,10],'bo')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()

# %%
import matplotlib.pyplot as plt

# color/shape/line style
# 'bo-' ==> 파란색 점 + 선
plt.plot([1,2,3,4],[2,3,5,10],'bo-')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()

# %%
import matplotlib.pyplot as plt

# color/shape/line style
# 'bo--' ==> 파란색 점 + 실선
plt.plot([1,2,3,4],[2,3,5,10],'bo--')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt

plt.plot([4,5,6], marker = "H")
plt.plot([3,4,5], marker = "d")
plt.plot([2,3,4], marker = "x")
plt.plot([1,2,3], marker = 11)
plt.plot([0,1,2], marker = "$Z$")
plt.show()

# %% [markdown]
# #### 08.Matplotlib 색상 지정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4],[2.0,3.0,5.0,10.0],'r')
plt.plot([1,2,3,4],[2.0,2.8,4.3,6.5],'g')
plt.plot([1,2,3,4],[2.0,2.5,3.3,4.5],'b')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(3,3))
plt.plot([1,2,3,4],[2.0,3.0,5.0,10.0],color = "limegreen")
plt.plot([1,2,3,4],[2.0,2.8,4.3,6.5],color = "violet")
plt.plot([1,2,3,4],[2.0,2.5,3.3,4.5],color="dodgerblue")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], color='#ffa9a9',marker='o', linestyle='--')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# Out:
# Text(0, 0.5, 'Y-Axis')

# %% [markdown]
# #### 09.Matplotlib 그래프 영역 채우기

# %%
# fill_between()

import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [2,3,5,10]

plt.plot(x,y)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill_between(x[1:3],y[1:3], alpha = 0.5)
